# %% [markdown]
# # Project 1

# %% [markdown]
# ## Step 1: Load the data and perform basic operations.

# %% [markdown]
# ##### 1. Load the data in using pandas.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
sns.set(color_codes = True)

# %%
# read csv and print head
act = pd.read_csv('../data/act.csv')
sat = pd.read_csv('../data/sat.csv')

# %%
del sat["Unnamed: 0"]

# %%
del act["Unnamed: 0"]

# %% [markdown]
# ##### 2. Print the first ten rows of each dataframe.

# %%
act.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#    Composite
# 0       21.0
# 1       19.2
# 2       19.8
# 3       19.7
# 4       19.4
# 5       22.8
# 6       20.8
# 7       25.2
# 8       24.1
# 9       24.2

# %%
act.head(52)
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# 12                Hawaii           90%     17.8  19.2     19.2     19.3
# 13                 Idaho           38%     21.9  21.8     23.0     22.1
# 14              Illinois           93%     21.0  21.2     21.6     21.3
# 15               Indiana           35%     22.0  22.4     23.2     22.3
# 16                  Iowa           67%     21.2  21.3     22.6     22.1
# 17                Kansas           73%     21.1  21.3     22.3     21.7
# 18              Kentucky          100%     19.6  19.4     20.5     20.1
# 19             Louisiana          100%     19.4  18.8     19.8     19.6
# 20                 Maine            8%     24.2  24.0     24.8     23.7
# 21              Maryland           28%     23.3  23.1     24.2     23.2
# 22         Massachusetts           29%     25.4  25.3     25.9     24.7
# 23              Michigan           29%     24.1  23.7     24.5     23.8
# 24             Minnesota          100%     20.4  21.5     21.8     21.6
# 25           Mississippi          100%     18.2  18.1     18.8     18.8
# 26              Missouri          100%     19.8  19.9     20.8     20.5
# 27               Montana          100%     19.0  20.2     21.0     20.5
# 28              Nebraska           84%     20.9  20.9     21.9     21.5
# 29                Nevada          100%     16.3  18.0     18.1     18.2
# 30         New Hampshire           18%     25.4  25.1     26.0     24.9
# 31            New Jersey           34%     23.8  23.8     24.1     23.2
# 32            New Mexico           66%     18.6  19.4     20.4     20.0
# 33              New York           31%     23.8  24.0     24.6     23.9
# 34        North Carolina          100%     17.8  19.3     19.6     19.3
# 35          North Dakota           98%     19.0  20.4     20.5     20.6
# 36                  Ohio           75%     21.2  21.6     22.5     22.0
# 37              Oklahoma          100%     18.5  18.8     20.1     19.6
# 38                Oregon           40%     21.2  21.5     22.4     21.7
# 39          Pennsylvania           23%     23.4  23.4     24.2     23.3
# 40          Rhode Island           21%     24.0  23.3     24.7     23.4
# 41        South Carolina          100%     17.5  18.6     19.1     18.9
# 42          South Dakota           80%     20.7  21.5     22.3     22.0
# 43             Tennessee          100%     19.5  19.2     20.1     19.9
# 44                 Texas           45%     19.5  20.7     21.1     20.9
# 45                  Utah          100%     19.5  19.9     20.8     20.6
# 46               Vermont           29%     23.3  23.1     24.4     23.2
# 47              Virginia           29%     23.5  23.3     24.6     23.5
# 48            Washington           29%     20.9  21.9     22.1     22.0
# 49         West Virginia           69%     20.0  19.4     21.2     20.5
# 50             Wisconsin          100%     19.7  20.4     20.6     20.9
# 51               Wyoming          100%     19.4  19.8     20.8     20.6
#
#     Composite
# 0        21.0
# 1        19.2
# 2        19.8
# 3        19.7
# 4        19.4
# 5        22.8
# 6        20.8
# 7        25.2
# 8        24.1
# 9        24.2
# 10       19.8
# 11       21.4
# 12       19.0
# 13       22.3
# 14       21.4
# 15       22.6
# 16       21.9
# 17       21.7
# 18       20.0
# 19       19.5
# 20       24.3
# 21       23.6
# 22       25.4
# 23       24.1
# 24       21.5
# 25       18.6
# 26       20.4
# 27       20.3
# 28       21.4
# 29       17.8
# 30       25.5
# 31       23.9
# 32       19.7
# 33       24.2
# 34       19.1
# 35       20.3
# 36       22.0
# 37       19.4
# 38       21.8
# 39       23.7
# 40       24.0
# 41       18.7
# 42       21.8
# 43       19.8
# 44       20.7
# 45       20.3
# 46       23.6
# 47       23.8
# 48       21.9
# 49       20.4
# 50       20.5
# 51       20.2

# %%
sat.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# 8   468    950
# 9   497   1017

# %%
sat.head(52)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# 11                Hawaii           55%                                 544
# 12                 Idaho           93%                                 513
# 13              Illinois            9%                                 559
# 14               Indiana           63%                                 542
# 15                  Iowa            2%                                 641
# 16                Kansas            4%                                 632
# 17              Kentucky            4%                                 631
# 18             Louisiana            4%                                 611
# 19                 Maine           95%                                 513
# 20              Maryland           69%                                 536
# 21         Massachusetts           76%                                 555
# 22              Michigan          100%                                 509
# 23             Minnesota            3%                                 644
# 24           Mississippi            2%                                 634
# 25              Missouri            3%                                 640
# 26               Montana           10%                                 605
# 27              Nebraska            3%                                 629
# 28                Nevada           26%                                 563
# 29         New Hampshire           96%                                 532
# 30            New Jersey           70%                                 530
# 31            New Mexico           11%                                 577
# 32              New York           67%                                 528
# 33        North Carolina           49%                                 546
# 34          North Dakota            2%                                 635
# 35                  Ohio           12%                                 578
# 36              Oklahoma            7%                                 530
# 37                Oregon           43%                                 560
# 38          Pennsylvania           65%                                 540
# 39          Rhode Island           71%                                 539
# 40        South Carolina           50%                                 543
# 41          South Dakota            3%                                 612
# 42             Tennessee            5%                                 623
# 43                 Texas           62%                                 513
# 44                  Utah            3%                                 624
# 45               Vermont           60%                                 562
# 46              Virginia           65%                                 561
# 47            Washington           64%                                 541
# 48         West Virginia           14%                                 558
# 49             Wisconsin            3%                                 642
# 50               Wyoming            3%                                 626
#
#     Math  Total
# 0    572   1165
# 1    533   1080
# 2    553   1116
# 3    594   1208
# 4    524   1055
# 5    595   1201
# 6    512   1041
# 7    492    996
# 8    468    950
# 9    497   1017
# 10   515   1050
# 11   541   1085
# 12   493   1005
# 13   556   1115
# 14   532   1074
# 15   635   1275
# 16   628   1260
# 17   616   1247
# 18   586   1198
# 19   499   1012
# 20   524   1060
# 21   551   1107
# 22   495   1005
# 23   651   1295
# 24   607   1242
# 25   631   1271
# 26   591   1196
# 27   625   1253
# 28   553   1116
# 29   520   1052
# 30   526   1056
# 31   561   1138
# 32   523   1052
# 33   535   1081
# 34   621   1256
# 35   570   1149
# 36   517   1047
# 37   548   1108
# 38   531   1071
# 39   524   1062
# 40   521   1064
# 41   603   1216
# 42   604   1228
# 43   507   1020
# 44   614   1238
# 45   551   1114
# 46   541   1102
# 47   534   1075
# 48   528   1086
# 49   649   1291
# 50   604   1230

# %% [markdown]
# ##### 3. Describe in words what each variable (column) is.

# %%
'''Act is composed of the following columns Unnamed, State, Participation, English, Math Reading, Science, Composite
Explaination of each column:
Unnamed:  This is the column that identifies the number of the row.
State:  What state the information in the row is from.
Participation:  The percentage of people who took the act in that state.
Evidence-Based Reading and Writing:  The score the participant received in reading comprehension and writing part of the exam.
Math:  The score the participant received in the math portion of the exam.
Total:
'''

# %%
'''SAT is composed of the following columns Unnamed, State, Participation, Evidence-Based Reading and 
Writing, Math, Total
Explaination of each column:
Unnamed:  This is the column that identifies the number of the row.
State:  What state the information in the row is from.
Participation:  The percentage of people who took the act in that state.
Evidence-Based Reading and Writing:  The score the participant received in reading comprehension and writing part of the exam.
Math:  The score the participant received in the math portion of the exam.
Total:
'''

# %% [markdown]
# ##### 4. Does the data look complete? Are there any obvious issues with the observations?

# %%
"""

"""

# %% [markdown]
# ##### 5. Print the types of each column.

# %%
act.dtypes
#https://stackoverflow.com/questions/22470690/get-list-of-pandas-dataframe-columns-based-on-data-type
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
sat.dtypes
#https://stackoverflow.com/questions/22470690/get-list-of-pandas-dataframe-columns-based-on-data-type
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# ##### 6. Do any types need to be reassigned? If so, go ahead and do it.

# %%
"""
Lower in the exercise I removed the percent from participation and turned the column into a collect integers

"""

# %% [markdown]
# ##### 7. Create a dictionary for each column mapping the State to its respective value for that column. (For example, you should have three SAT dictionaries.)

# %%
"""
SAT will need to be State: Participation, State:Evidence-Based Reading, and Writing State:Math
state: sat_part, state: sat_reading, state: sat_math
ACT will need to be 
"""

# %%
sat_part = sat[["State", "Participation"]]
sat_reading = sat[["State", "Evidence-Based Reading and Writing"]]
sat_math = sat[["State", "Math"]]
sat_partd = sat_part.set_index('State').to_dict()
sat_readingd = sat_reading.set_index('State').to_dict()
sat_mathd = sat_math.set_index('State').to_dict()
#https://stackoverflow.com/questions/18695605/python-pandas-dataframe-to-dictionary
#sat_part

# %%
sat_partd
# Out:
# {'Participation': {'Alabama': '5%',
#   'Alaska': '38%',
#   'Arizona': '30%',
#   'Arkansas': '3%',
#   'California': '53%',
#   'Colorado': '11%',
#   'Connecticut': '100%',
#   'Delaware': '100%',
#   'District of Columbia': '100%',
#   'Florida': '83%',
#   'Georgia': '61%',
#   'Hawaii': '55%',
#   'Idaho': '93%',
#   'Illinois': '9%',
#   'Indiana': '63%',
#   'Iowa': '2%',
#   'Kansas': '4%',
#   'Kentucky': '4%',
#   'Louisiana': '4%',
#   'Maine': '95%',
#   'Maryland': '69%',
#   'Massachusetts': '76%',
#   'Michigan': '100%',
#   'Minnesota': '3%',
#   'Mississippi': '2%',
#   'Missouri': '3%',
#   'Montana': '10%',
#   'Nebraska': '3%',
#   'Nevada': '26%',
#   'New Hampshire': '96%',
#   'New Jersey': '70%',
#   'New Mexico': '11%',
#   'New York': '67%',
#   'North Carolina': '49%',
#   'North Dakota': '2%',
#   'Ohio': '12%',
#   'Oklahoma': '7%',
#   'Oregon': '43%',
#   'Pennsylvania': '65%',
#   'Rhode Island': '71%',
#   'South Carolina': '50%',
#   'South Dakota': '3%',
#   'Tennessee': '5%',
#   'Texas': '62%',
#   'Utah': '3%',
#   'Vermont': '60%',
#   'Virginia': '65%',
#   'Washington': '64%',
#   'West Virginia': '14%',
#   'Wisconsin': '3%',
#   'Wyoming': '3%'}}

# %%
sat_readingd
# Out:
# {'Evidence-Based Reading and Writing': {'Alabama': 593,
#   'Alaska': 547,
#   'Arizona': 563,
#   'Arkansas': 614,
#   'California': 531,
#   'Colorado': 606,
#   'Connecticut': 530,
#   'Delaware': 503,
#   'District of Columbia': 482,
#   'Florida': 520,
#   'Georgia': 535,
#   'Hawaii': 544,
#   'Idaho': 513,
#   'Illinois': 559,
#   'Indiana': 542,
#   'Iowa': 641,
#   'Kansas': 632,
#   'Kentucky': 631,
#   'Louisiana': 611,
#   'Maine': 513,
#   'Maryland': 536,
#   'Massachusetts': 555,
#   'Michigan': 509,
#   'Minnesota': 644,
#   'Mississippi': 634,
#   'Missouri': 640,
#   'Montana': 605,
#   'Nebraska': 629,
#   'Nevada': 563,
#   'New Hampshire': 532,
#   'New Jersey': 530,
#   'New Mexico': 577,
#   'New York': 528,
#   'North Carolina': 546,
#   'North Dakota': 635,
#   'Ohio': 578,
#   'Oklahoma': 530,
#   'Oregon': 560,
#   'Pennsylvania': 540,
#   'Rhode Island': 539,
#   'South Carolina': 543,
#   'South Dakota': 612,
#   'Tennessee': 623,
#   'Texas': 513,
#   'Utah': 624,
#   'Vermont': 562,
#   'Virginia': 561,
#   'Washington': 541,
#   'West Virginia': 558,
#   'Wisconsin': 642,
#   'Wyoming': 626}}

# %%
sat_mathd
# Out:
# {'Math': {'Alabama': 572,
#   'Alaska': 533,
#   'Arizona': 553,
#   'Arkansas': 594,
#   'California': 524,
#   'Colorado': 595,
#   'Connecticut': 512,
#   'Delaware': 492,
#   'District of Columbia': 468,
#   'Florida': 497,
#   'Georgia': 515,
#   'Hawaii': 541,
#   'Idaho': 493,
#   'Illinois': 556,
#   'Indiana': 532,
#   'Iowa': 635,
#   'Kansas': 628,
#   'Kentucky': 616,
#   'Louisiana': 586,
#   'Maine': 499,
#   'Maryland': 524,
#   'Massachusetts': 551,
#   'Michigan': 495,
#   'Minnesota': 651,
#   'Mississippi': 607,
#   'Missouri': 631,
#   'Montana': 591,
#   'Nebraska': 625,
#   'Nevada': 553,
#   'New Hampshire': 520,
#   'New Jersey': 526,
#   'New Mexico': 561,
#   'New York': 523,
#   'North Carolina': 535,
#   'North Dakota': 621,
#   'Ohio': 570,
#   'Oklahoma': 517,
#   'Oregon': 548,
#   'Pennsylvania': 531,
#   'Rhode Island': 524,
#   'South Carolina': 521,
#   'South Dakota': 603,
#   'Tennessee': 604,
#   'Texas': 507,
#   'Utah': 614,
#   'Vermont': 551,
#   'Virginia': 541,
#   'Washington': 534,
#   'West Virginia': 528,
#   'Wisconsin': 649,
#   'Wyoming': 604}}

# %%
act_part = act[["State", "Participation"]]
act_english = act[["State", "English"]]
act_math = act[["State", "Math"]]
act_reading = act[["State", "Reading"]]
act_science = act[["State", "Science"]]
act_partd = act_part.set_index('State').to_dict()
act_englishd = act_english.set_index('State').to_dict()
act_mathd = act_math.set_index('State').to_dict()
act_readingd = act_reading.set_index('State').to_dict()
act_scienced = act_science.set_index('State').to_dict()
#https://stackoverflow.com/questions/18695605/python-pandas-dataframe-to-dictionary
#sat_part

# %%
act_englishd
# Out:
# {'English': {'Alabama': 18.899999999999999,
#   'Alaska': 18.699999999999999,
#   'Arizona': 18.600000000000001,
#   'Arkansas': 18.899999999999999,
#   'California': 22.5,
#   'Colorado': 20.100000000000001,
#   'Connecticut': 25.5,
#   'Delaware': 24.100000000000001,
#   'District of Columbia': 24.399999999999999,
#   'Florida': 19.0,
#   'Georgia': 21.0,
#   'Hawaii': 17.800000000000001,
#   'Idaho': 21.899999999999999,
#   'Illinois': 21.0,
#   'Indiana': 22.0,
#   'Iowa': 21.199999999999999,
#   'Kansas': 21.100000000000001,
#   'Kentucky': 19.600000000000001,
#   'Louisiana': 19.399999999999999,
#   'Maine': 24.199999999999999,
#   'Maryland': 23.300000000000001,
#   'Massachusetts': 25.399999999999999,
#   'Michigan': 24.100000000000001,
#   'Minnesota': 20.399999999999999,
#   'Mississippi': 18.199999999999999,
#   'Missouri': 19.800000000000001,
#   'Montana': 19.0,
#   'National': 20.300000000000001,
#   'Nebraska': 20.899999999999999,
#   'Nevada': 16.300000000000001,
#   'New Hampshire': 25.399999999999999,
#   'New Jersey': 23.800000000000001,
#   'New Mexico': 18.600000000000001,
#   'New York': 23.800000000000001,
#   'North Carolina': 17.800000000000001,
#   'North Dakota': 19.0,
#   'Ohio': 21.199999999999999,
#   'Oklahoma': 18.5,
#   'Oregon': 21.199999999999999,
#   'Pennsylvania': 23.399999999999999,
#   'Rhode Island': 24.0,
#   'South Carolina': 17.5,
#   'South Dakota': 20.699999999999999,
#   'Tennessee': 19.5,
#   'Texas': 19.5,
#   'Utah': 19.5,
#   'Vermont': 23.300000000000001,
#   'Virginia': 23.5,
#   'Washington': 20.899999999999999,
#   'West Virginia': 20.0,
#   'Wisconsin': 19.699999999999999,
#   'Wyoming': 19.399999999999999}}

# %%
act_mathd
# Out:
# {'Math': {'Alabama': 18.399999999999999,
#   'Alaska': 19.800000000000001,
#   'Arizona': 19.800000000000001,
#   'Arkansas': 19.0,
#   'California': 22.699999999999999,
#   'Colorado': 20.300000000000001,
#   'Connecticut': 24.600000000000001,
#   'Delaware': 23.399999999999999,
#   'District of Columbia': 23.5,
#   'Florida': 19.399999999999999,
#   'Georgia': 20.899999999999999,
#   'Hawaii': 19.199999999999999,
#   'Idaho': 21.800000000000001,
#   'Illinois': 21.199999999999999,
#   'Indiana': 22.399999999999999,
#   'Iowa': 21.300000000000001,
#   'Kansas': 21.300000000000001,
#   'Kentucky': 19.399999999999999,
#   'Louisiana': 18.800000000000001,
#   'Maine': 24.0,
#   'Maryland': 23.100000000000001,
#   'Massachusetts': 25.300000000000001,
#   'Michigan': 23.699999999999999,
#   'Minnesota': 21.5,
#   'Mississippi': 18.100000000000001,
#   'Missouri': 19.899999999999999,
#   'Montana': 20.199999999999999,
#   'National': 20.699999999999999,
#   'Nebraska': 20.899999999999999,
#   'Nevada': 18.0,
#   'New Hampshire': 25.100000000000001,
#   'New Jersey': 23.800000000000001,
#   'New Mexico': 19.399999999999999,
#   'New York': 24.0,
#   'North Carolina': 19.300000000000001,
#   'North Dakota': 20.399999999999999,
#   'Ohio': 21.600000000000001,
#   'Oklahoma': 18.800000000000001,
#   'Oregon': 21.5,
#   'Pennsylvania': 23.399999999999999,
#   'Rhode Island': 23.300000000000001,
#   'South Carolina': 18.600000000000001,
#   'South Dakota': 21.5,
#   'Tennessee': 19.199999999999999,
#   'Texas': 20.699999999999999,
#   'Utah': 19.899999999999999,
#   'Vermont': 23.100000000000001,
#   'Virginia': 23.300000000000001,
#   'Washington': 21.899999999999999,
#   'West Virginia': 19.399999999999999,
#   'Wisconsin': 20.399999999999999,
#   'Wyoming': 19.800000000000001}}

# %%
act_readingd
# Out:
# {'Reading': {'Alabama': 19.699999999999999,
#   'Alaska': 20.399999999999999,
#   'Arizona': 20.100000000000001,
#   'Arkansas': 19.699999999999999,
#   'California': 23.100000000000001,
#   'Colorado': 21.199999999999999,
#   'Connecticut': 25.600000000000001,
#   'Delaware': 24.800000000000001,
#   'District of Columbia': 24.899999999999999,
#   'Florida': 21.0,
#   'Georgia': 22.0,
#   'Hawaii': 19.199999999999999,
#   'Idaho': 23.0,
#   'Illinois': 21.600000000000001,
#   'Indiana': 23.199999999999999,
#   'Iowa': 22.600000000000001,
#   'Kansas': 22.300000000000001,
#   'Kentucky': 20.5,
#   'Louisiana': 19.800000000000001,
#   'Maine': 24.800000000000001,
#   'Maryland': 24.199999999999999,
#   'Massachusetts': 25.899999999999999,
#   'Michigan': 24.5,
#   'Minnesota': 21.800000000000001,
#   'Mississippi': 18.800000000000001,
#   'Missouri': 20.800000000000001,
#   'Montana': 21.0,
#   'National': 21.399999999999999,
#   'Nebraska': 21.899999999999999,
#   'Nevada': 18.100000000000001,
#   'New Hampshire': 26.0,
#   'New Jersey': 24.100000000000001,
#   'New Mexico': 20.399999999999999,
#   'New York': 24.600000000000001,
#   'North Carolina': 19.600000000000001,
#   'North Dakota': 20.5,
#   'Ohio': 22.5,
#   'Oklahoma': 20.100000000000001,
#   'Oregon': 22.399999999999999,
#   'Pennsylvania': 24.199999999999999,
#   'Rhode Island': 24.699999999999999,
#   'South Carolina': 19.100000000000001,
#   'South Dakota': 22.300000000000001,
#   'Tennessee': 20.100000000000001,
#   'Texas': 21.100000000000001,
#   'Utah': 20.800000000000001,
#   'Vermont': 24.399999999999999,
#   'Virginia': 24.600000000000001,
#   'Washington': 22.100000000000001,
#   'West Virginia': 21.199999999999999,
#   'Wisconsin': 20.600000000000001,
#   'Wyoming': 20.800000000000001}}

# %%
act_scienced
# Out:
# {'Science': {'Alabama': 19.399999999999999,
#   'Alaska': 19.899999999999999,
#   'Arizona': 19.800000000000001,
#   'Arkansas': 19.5,
#   'California': 22.199999999999999,
#   'Colorado': 20.899999999999999,
#   'Connecticut': 24.600000000000001,
#   'Delaware': 23.600000000000001,
#   'District of Columbia': 23.5,
#   'Florida': 19.399999999999999,
#   'Georgia': 21.300000000000001,
#   'Hawaii': 19.300000000000001,
#   'Idaho': 22.100000000000001,
#   'Illinois': 21.300000000000001,
#   'Indiana': 22.300000000000001,
#   'Iowa': 22.100000000000001,
#   'Kansas': 21.699999999999999,
#   'Kentucky': 20.100000000000001,
#   'Louisiana': 19.600000000000001,
#   'Maine': 23.699999999999999,
#   'Maryland': 23.199999999999999,
#   'Massachusetts': 24.699999999999999,
#   'Michigan': 23.800000000000001,
#   'Minnesota': 21.600000000000001,
#   'Mississippi': 18.800000000000001,
#   'Missouri': 20.5,
#   'Montana': 20.5,
#   'National': 21.0,
#   'Nebraska': 21.5,
#   'Nevada': 18.199999999999999,
#   'New Hampshire': 24.899999999999999,
#   'New Jersey': 23.199999999999999,
#   'New Mexico': 20.0,
#   'New York': 23.899999999999999,
#   'North Carolina': 19.300000000000001,
#   'North Dakota': 20.600000000000001,
#   'Ohio': 22.0,
#   'Oklahoma': 19.600000000000001,
#   'Oregon': 21.699999999999999,
#   'Pennsylvania': 23.300000000000001,
#   'Rhode Island': 23.399999999999999,
#   'South Carolina': 18.899999999999999,
#   'South Dakota': 22.0,
#   'Tennessee': 19.899999999999999,
#   'Texas': 20.899999999999999,
#   'Utah': 20.600000000000001,
#   'Vermont': 23.199999999999999,
#   'Virginia': 23.5,
#   'Washington': 22.0,
#   'West Virginia': 20.5,
#   'Wisconsin': 20.899999999999999,
#   'Wyoming': 20.600000000000001}}

# %% [markdown]
# ##### 8. Create one dictionary where each key is the column name, and each value is an iterable (a list or a Pandas Series) of all the values in that column.

# %%
dict_data = act.set_index('State')['Participation'].to_dict()
dict_data
# Out:
# {'Alabama': '100%',
#  'Alaska': '65%',
#  'Arizona': '62%',
#  'Arkansas': '100%',
#  'California': '31%',
#  'Colorado': '100%',
#  'Connecticut': '31%',
#  'Delaware': '18%',
#  'District of Columbia': '32%',
#  'Florida': '73%',
#  'Georgia': '55%',
#  'Hawaii': '90%',
#  'Idaho': '38%',
#  'Illinois': '93%',
#  'Indiana': '35%',
#  'Iowa': '67%',
#  'Kansas': '73%',
#  'Kentucky': '100%',
#  'Louisiana': '100%',
#  'Maine': '8%',
#  'Maryland': '28%',
#  'Massachusetts': '29%',
#  'Michigan': '29%',
#  'Minnesota': '100%',
#  'Mississippi': '100%',
#  'Missouri': '100%',
#  'Montana': '100%',
#  'National': ' 60%',
#  'Nebraska': '84%',
#  'Nevada': '100%',
#  'New Hampshire': '18%',
#  'New Jersey': '34%',
#  'New Mexico': '66%',
#  'New York': '31%',
#  'North Carolina': '100%',
#  'North Dakota': '98%',
#  'Ohio': '75%',
#  'Oklahoma': '100%',
#  'Oregon': '40%',
#  'Pennsylvania': '23%',
#  'Rhode Island': '21%',
#  'South Carolina': '100%',
#  'South Dakota': '80%',
#  'Tennessee': '100%',
#  'Texas': '45%',
#  'Utah': '100%',
#  'Vermont': '29%',
#  'Virginia': '29%',
#  'Washington': '29%',
#  'West Virginia': '69%',
#  'Wisconsin': '100%',
#  'Wyoming': '100%'}

# %% [markdown]
# ##### 9. Merge the dataframes on the state column.

# %%
both = pd.merge(sat, act, on = "State")
#I am merging the two datasets on the State column
#pd.merge(df1, df2, on="state")

# %%
both
#Verifying that everything merged.
# Out:
#                    State Participation_x  Evidence-Based Reading and Writing  \
# 0                Alabama              5%                                 593
# 1                 Alaska             38%                                 547
# 2                Arizona             30%                                 563
# 3               Arkansas              3%                                 614
# 4             California             53%                                 531
# 5               Colorado             11%                                 606
# 6            Connecticut            100%                                 530
# 7               Delaware            100%                                 503
# 8   District of Columbia            100%                                 482
# 9                Florida             83%                                 520
# 10               Georgia             61%                                 535
# 11                Hawaii             55%                                 544
# 12                 Idaho             93%                                 513
# 13              Illinois              9%                                 559
# 14               Indiana             63%                                 542
# 15                  Iowa              2%                                 641
# 16                Kansas              4%                                 632
# 17              Kentucky              4%                                 631
# 18             Louisiana              4%                                 611
# 19                 Maine             95%                                 513
# 20              Maryland             69%                                 536
# 21         Massachusetts             76%                                 555
# 22              Michigan            100%                                 509
# 23             Minnesota              3%                                 644
# 24           Mississippi              2%                                 634
# 25              Missouri              3%                                 640
# 26               Montana             10%                                 605
# 27              Nebraska              3%                                 629
# 28                Nevada             26%                                 563
# 29         New Hampshire             96%                                 532
# 30            New Jersey             70%                                 530
# 31            New Mexico             11%                                 577
# 32              New York             67%                                 528
# 33        North Carolina             49%                                 546
# 34          North Dakota              2%                                 635
# 35                  Ohio             12%                                 578
# 36              Oklahoma              7%                                 530
# 37                Oregon             43%                                 560
# 38          Pennsylvania             65%                                 540
# 39          Rhode Island             71%                                 539
# 40        South Carolina             50%                                 543
# 41          South Dakota              3%                                 612
# 42             Tennessee              5%                                 623
# 43                 Texas             62%                                 513
# 44                  Utah              3%                                 624
# 45               Vermont             60%                                 562
# 46              Virginia             65%                                 561
# 47            Washington             64%                                 541
# 48         West Virginia             14%                                 558
# 49             Wisconsin              3%                                 642
# 50               Wyoming              3%                                 626
#
#     Math_x  Total Participation_y  English  Math_y  Reading  Science  \
# 0      572   1165            100%     18.9    18.4     19.7     19.4
# 1      533   1080             65%     18.7    19.8     20.4     19.9
# 2      553   1116             62%     18.6    19.8     20.1     19.8
# 3      594   1208            100%     18.9    19.0     19.7     19.5
# 4      524   1055             31%     22.5    22.7     23.1     22.2
# 5      595   1201            100%     20.1    20.3     21.2     20.9
# 6      512   1041             31%     25.5    24.6     25.6     24.6
# 7      492    996             18%     24.1    23.4     24.8     23.6
# 8      468    950             32%     24.4    23.5     24.9     23.5
# 9      497   1017             73%     19.0    19.4     21.0     19.4
# 10     515   1050             55%     21.0    20.9     22.0     21.3
# 11     541   1085             90%     17.8    19.2     19.2     19.3
# 12     493   1005             38%     21.9    21.8     23.0     22.1
# 13     556   1115             93%     21.0    21.2     21.6     21.3
# 14     532   1074             35%     22.0    22.4     23.2     22.3
# 15     635   1275             67%     21.2    21.3     22.6     22.1
# 16     628   1260             73%     21.1    21.3     22.3     21.7
# 17     616   1247            100%     19.6    19.4     20.5     20.1
# 18     586   1198            100%     19.4    18.8     19.8     19.6
# 19     499   1012              8%     24.2    24.0     24.8     23.7
# 20     524   1060             28%     23.3    23.1     24.2     23.2
# 21     551   1107             29%     25.4    25.3     25.9     24.7
# 22     495   1005             29%     24.1    23.7     24.5     23.8
# 23     651   1295            100%     20.4    21.5     21.8     21.6
# 24     607   1242            100%     18.2    18.1     18.8     18.8
# 25     631   1271            100%     19.8    19.9     20.8     20.5
# 26     591   1196            100%     19.0    20.2     21.0     20.5
# 27     625   1253             84%     20.9    20.9     21.9     21.5
# 28     553   1116            100%     16.3    18.0     18.1     18.2
# 29     520   1052             18%     25.4    25.1     26.0     24.9
# 30     526   1056             34%     23.8    23.8     24.1     23.2
# 31     561   1138             66%     18.6    19.4     20.4     20.0
# 32     523   1052             31%     23.8    24.0     24.6     23.9
# 33     535   1081            100%     17.8    19.3     19.6     19.3
# 34     621   1256             98%     19.0    20.4     20.5     20.6
# 35     570   1149             75%     21.2    21.6     22.5     22.0
# 36     517   1047            100%     18.5    18.8     20.1     19.6
# 37     548   1108             40%     21.2    21.5     22.4     21.7
# 38     531   1071             23%     23.4    23.4     24.2     23.3
# 39     524   1062             21%     24.0    23.3     24.7     23.4
# 40     521   1064            100%     17.5    18.6     19.1     18.9
# 41     603   1216             80%     20.7    21.5     22.3     22.0
# 42     604   1228            100%     19.5    19.2     20.1     19.9
# 43     507   1020             45%     19.5    20.7     21.1     20.9
# 44     614   1238            100%     19.5    19.9     20.8     20.6
# 45     551   1114             29%     23.3    23.1     24.4     23.2
# 46     541   1102             29%     23.5    23.3     24.6     23.5
# 47     534   1075             29%     20.9    21.9     22.1     22.0
# 48     528   1086             69%     20.0    19.4     21.2     20.5
# 49     649   1291            100%     19.7    20.4     20.6     20.9
# 50     604   1230            100%     19.4    19.8     20.8     20.6
#
#     Composite
# 0        19.2
# 1        19.8
# 2        19.7
# 3        19.4
# 4        22.8
# 5        20.8
# 6        25.2
# 7        24.1
# 8        24.2
# 9        19.8
# 10       21.4
# 11       19.0
# 12       22.3
# 13       21.4
# 14       22.6
# 15       21.9
# 16       21.7
# 17       20.0
# 18       19.5
# 19       24.3
# 20       23.6
# 21       25.4
# 22       24.1
# 23       21.5
# 24       18.6
# 25       20.4
# 26       20.3
# 27       21.4
# 28       17.8
# 29       25.5
# 30       23.9
# 31       19.7
# 32       24.2
# 33       19.1
# 34       20.3
# 35       22.0
# 36       19.4
# 37       21.8
# 38       23.7
# 39       24.0
# 40       18.7
# 41       21.8
# 42       19.8
# 43       20.7
# 44       20.3
# 45       23.6
# 46       23.8
# 47       21.9
# 48       20.4
# 49       20.5
# 50       20.2

# %% [markdown]
# ##### 10. Change the names of the columns so you can distinguish between the SAT columns and the ACT columns.

# %%
both.rename(columns = {"Participation_x":"SAT Participation Percent","Evidence-Based Reading and Writing":"SAT Reading and Writing", "Math_x":"SAT Math", "Total": "SAT Total", "Participation_y": "ACT Participation Percent", "English": "ACT English", "Math_y": "ACT Math", "Reading": "ACT Reading", "Science": "ACT_Science", "Composite": "ACT Composite"}, inplace = True)

# %%
both.head(2)
# Out:
#      State SAT Participation Percent  SAT Reading and Writing  SAT Math  \
# 0  Alabama                        5%                      593       572
# 1   Alaska                       38%                      547       533
#
#    SAT Total ACT Participation Percent  ACT English  ACT Math  ACT Reading  \
# 0       1165                      100%         18.9      18.4         19.7
# 1       1080                       65%         18.7      19.8         20.4
#
#    ACT_Science  ACT Composite
# 0         19.4           19.2
# 1         19.9           19.8

# %%
both['SAT Participation Percent'] = both['SAT Participation Percent'].apply(lambda x: x[:-1]) #Slicing the % off every column
both['ACT Participation Percent'] = both['ACT Participation Percent'].apply(lambda x: x[:-1]) #Slicing the % off every column
both['SAT Participation Percent'] = both['SAT Participation Percent'].astype(int) #Converting str to a int
both['ACT Participation Percent'] = both['ACT Participation Percent'].astype(int) #Converting str to a int
both.dtypes #Confirming change
# Out:
# State                         object
# SAT Participation Percent      int64
# SAT Reading and Writing        int64
# SAT Math                       int64
# SAT Total                      int64
# ACT Participation Percent      int64
# ACT English                  float64
# ACT Math                     float64
# ACT Reading                  float64
# ACT_Science                  float64
# ACT Composite                float64
# dtype: object

# %% [markdown]
# ##### 11. Print the minimum and maximum of each numeric column in the data frame.

# %%
both.describe()
#the describe function describes the minimum and maximum for all columns
# Out:
#        Evidence-Based Reading and Writing      Math_x        Total    English  \
# count                           51.000000   51.000000    51.000000  51.000000
# mean                           569.117647  556.882353  1126.098039  20.931373
# std                             45.666901   47.121395    92.494812   2.353677
# min                            482.000000  468.000000   950.000000  16.300000
# 25%                            533.500000  523.500000  1055.500000  19.000000
# 50%                            559.000000  548.000000  1107.000000  20.700000
# 75%                            613.000000  599.000000  1212.000000  23.300000
# max                            644.000000  651.000000  1295.000000  25.500000
#
#           Math_y    Reading    Science  Composite
# count  51.000000  51.000000  51.000000  51.000000
# mean   21.182353  22.013725  21.450980  21.519608
# std     1.981989   2.067271   1.739353   2.020695
# min    18.000000  18.100000  18.200000  17.800000
# 25%    19.400000  20.450000  19.950000  19.800000
# 50%    20.900000  21.800000  21.300000  21.400000
# 75%    23.100000  24.150000  23.200000  23.600000
# max    25.300000  26.000000  24.900000  25.500000

# %% [markdown]
# ##### 12. Write a function using only list comprehensions, no loops, to compute standard deviation. Using this function, calculate the standard deviation of each numeric column in both data sets. Add these to a list called `sd`.
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$

# %%
import numpy as np
both.drop(["State"], axis = 1)
def stdv(both): #Returns the standard deviation of a numeric list
    mn = np.mean(both)
    variance = sum([(i-mn)**2 for i in both]) / len(both) 
    return variance ** .5
#the equation for standard deviation
#drinks.drop(['mL', 'servings'], axis=1, inplace=True)

# %%
stdv(both["SAT Math"])
#testing out the standard deviation equation on a column to verify it works
# Out:
# 46.65713364485503

# %%
stdv(both["SAT Participation Percent"])
#testing out the standard deviation equation on another column
# Out:
# 34.929070766645083

# %%
sd = []

for col in both.columns:
    try:
        sd.append(stdv(both[col]))
    except:
        print('wrong data type')
sd    
#getting rid of the state so the standard deviation column can be applied to the dataset and not error out.
# Out:
# wrong data type
# [34.929070766645083,
#  45.216970204378661,
#  46.65713364485503,
#  91.583510567787428,
#  31.824175751231806,
#  2.3304876369363363,
#  1.9624620273436781,
#  2.0469029314842646,
#  1.7222161451443676,
#  2.0007860815819889]

# %% [markdown]
# ## Step 2: Manipulate the dataframe

# %% [markdown]
# ##### 13. Turn the list `sd` into a new observation in your dataset.

# %%
sd
#Trying to figure out how to add a title for the row so it isn't off by one variable
# Out:
# [34.929070766645083,
#  45.216970204378661,
#  46.65713364485503,
#  91.583510567787428,
#  31.824175751231806,
#  2.3304876369363363,
#  1.9624620273436781,
#  2.0469029314842646,
#  1.7222161451443676,
#  2.0007860815819889]

# %%
name_add_sd = "Standard Deviation"
sd_list = [name_add_sd] + sd
#added the title standard deviation to the row

# %%
sd_both = both[sd_list]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-209-105a3b2c1ae2> in <module>()
# ----> 1 sd_both = both[sd_list]
#
# /Users/ksantana/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /Users/ksantana/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /Users/ksantana/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['Standard Deviation' 34.929070766645083 45.216970204378661\n 46.65713364485503 91.583510567787428 31.824175751231806 2.3304876369363363\n 1.9624620273436781 2.0469029314842646 1.7222161451443676\n 2.0007860815819889] not in index"

# %%
sd_both
# Out:
#                                      State SAT Participation Percent  \
# 0                AlabamaStandard Deviation                   39.9291
# 1                 AlaskaStandard Deviation                   72.9291
# 2                ArizonaStandard Deviation                   64.9291
# 3               ArkansasStandard Deviation                   37.9291
# 4             CaliforniaStandard Deviation                   87.9291
# 5               ColoradoStandard Deviation                   45.9291
# 6            ConnecticutStandard Deviation                   134.929
# 7               DelawareStandard Deviation                   134.929
# 8   District of ColumbiaStandard Deviation                   134.929
# 9                FloridaStandard Deviation                   117.929
# 10               GeorgiaStandard Deviation                   95.9291
# 11                HawaiiStandard Deviation                   89.9291
# 12                 IdahoStandard Deviation                   127.929
# 13              IllinoisStandard Deviation                   43.9291
# 14               IndianaStandard Deviation                   97.9291
# 15                  IowaStandard Deviation                   36.9291
# 16                KansasStandard Deviation                   38.9291
# 17              KentuckyStandard Deviation                   38.9291
# 18             LouisianaStandard Deviation                   38.9291
# 19                 MaineStandard Deviation                   129.929
# 20              MarylandStandard Deviation                   103.929
# 21         MassachusettsStandard Deviation                   110.929
# 22              MichiganStandard Deviation                   134.929
# 23             MinnesotaStandard Deviation                   37.9291
# 24           MississippiStandard Deviation                   36.9291
# 25              MissouriStandard Deviation                   37.9291
# 26               MontanaStandard Deviation                   44.9291
# 27              NebraskaStandard Deviation                   37.9291
# 28                NevadaStandard Deviation                   60.9291
# 29         New HampshireStandard Deviation                   130.929
# 30            New JerseyStandard Deviation                   104.929
# 31            New MexicoStandard Deviation                   45.9291
# 32              New YorkStandard Deviation                   101.929
# 33        North CarolinaStandard Deviation                   83.9291
# 34          North DakotaStandard Deviation                   36.9291
# 35                  OhioStandard Deviation                   46.9291
# 36              OklahomaStandard Deviation                   41.9291
# 37                OregonStandard Deviation                   77.9291
# 38          PennsylvaniaStandard Deviation                   99.9291
# 39          Rhode IslandStandard Deviation                   105.929
# 40        South CarolinaStandard Deviation                   84.9291
# 41          South DakotaStandard Deviation                   37.9291
# 42             TennesseeStandard Deviation                   39.9291
# 43                 TexasStandard Deviation                   96.9291
# 44                  UtahStandard Deviation                   37.9291
# 45               VermontStandard Deviation                   94.9291
# 46              VirginiaStandard Deviation                   99.9291
# 47            WashingtonStandard Deviation                   98.9291
# 48         West VirginiaStandard Deviation                   48.9291
# 49             WisconsinStandard Deviation                   37.9291
# 50               WyomingStandard Deviation                   37.9291
#
#    SAT Reading and Writing SAT Math SAT Total ACT Participation Percent  \
# 0                  638.217  618.657   1256.58                   131.824
# 1                  592.217  579.657   1171.58                   96.8242
# 2                  608.217  599.657   1207.58                   93.8242
# 3                  659.217  640.657   1299.58                   131.824
# 4                  576.217  570.657   1146.58                   62.8242
# 5                  651.217  641.657   1292.58                   131.824
# 6                  575.217  558.657   1132.58                   62.8242
# 7                  548.217  538.657   1087.58                   49.8242
# 8                  527.217  514.657   1041.58                   63.8242
# 9                  565.217  543.657   1108.58                   104.824
# 10                 580.217  561.657   1141.58                   86.8242
# 11                 589.217  587.657   1176.58                   121.824
# 12                 558.217  539.657   1096.58                   69.8242
# 13                 604.217  602.657   1206.58                   124.824
# 14                 587.217  578.657   1165.58                   66.8242
# 15                 686.217  681.657   1366.58                   98.8242
# 16                 677.217  674.657   1351.58                   104.824
# 17                 676.217  662.657   1338.58                   131.824
# 18                 656.217  632.657   1289.58                   131.824
# 19                 558.217  545.657   1103.58                   39.8242
# 20                 581.217  570.657   1151.58                   59.8242
# 21                 600.217  597.657   1198.58                   60.8242
# 22                 554.217  541.657   1096.58                   60.8242
# 23                 689.217  697.657   1386.58                   131.824
# 24                 679.217  653.657   1333.58                   131.824
# 25                 685.217  677.657   1362.58                   131.824
# 26                 650.217  637.657   1287.58                   131.824
# 27                 674.217  671.657   1344.58                   115.824
# 28                 608.217  599.657   1207.58                   131.824
# 29                 577.217  566.657   1143.58                   49.8242
# 30                 575.217  572.657   1147.58                   65.8242
# 31                 622.217  607.657   1229.58                   97.8242
# 32                 573.217  569.657   1143.58                   62.8242
# 33                 591.217  581.657   1172.58                   131.824
# 34                 680.217  667.657   1347.58                   129.824
# 35                 623.217  616.657   1240.58                   106.824
# 36                 575.217  563.657   1138.58                   131.824
# 37                 605.217  594.657   1199.58                   71.8242
# 38                 585.217  577.657   1162.58                   54.8242
# 39                 584.217  570.657   1153.58                   52.8242
# 40                 588.217  567.657   1155.58                   131.824
# 41                 657.217  649.657   1307.58                   111.824
# 42                 668.217  650.657   1319.58                   131.824
# 43                 558.217  553.657   1111.58                   76.8242
# 44                 669.217  660.657   1329.58                   131.824
# 45                 607.217  597.657   1205.58                   60.8242
# 46                 606.217  587.657   1193.58                   60.8242
# 47                 586.217  580.657   1166.58                   60.8242
# 48                 603.217  574.657   1177.58                   100.824
# 49                 687.217  695.657   1382.58                   131.824
# 50                 671.217  650.657   1321.58                   131.824
#
#    ACT English ACT Math ACT Reading ACT_Science ACT Composite
# 0      21.2305  20.3625     21.7469     21.1222       21.2008
# 1      21.0305  21.7625     22.4469     21.6222       21.8008
# 2      20.9305  21.7625     22.1469     21.5222       21.7008
# 3      21.2305  20.9625     21.7469     21.2222       21.4008
# 4      24.8305  24.6625     25.1469     23.9222       24.8008
# 5      22.4305  22.2625     23.2469     22.6222       22.8008
# 6      27.8305  26.5625     27.6469     26.3222       27.2008
# 7      26.4305  25.3625     26.8469     25.3222       26.1008
# 8      26.7305  25.4625     26.9469     25.2222       26.2008
# 9      21.3305  21.3625     23.0469     21.1222       21.8008
# 10     23.3305  22.8625     24.0469     23.0222       23.4008
# 11     20.1305  21.1625     21.2469     21.0222       21.0008
# 12     24.2305  23.7625     25.0469     23.8222       24.3008
# 13     23.3305  23.1625     23.6469     23.0222       23.4008
# 14     24.3305  24.3625     25.2469     24.0222       24.6008
# 15     23.5305  23.2625     24.6469     23.8222       23.9008
# 16     23.4305  23.2625     24.3469     23.4222       23.7008
# 17     21.9305  21.3625     22.5469     21.8222       22.0008
# 18     21.7305  20.7625     21.8469     21.3222       21.5008
# 19     26.5305  25.9625     26.8469     25.4222       26.3008
# 20     25.6305  25.0625     26.2469     24.9222       25.6008
# 21     27.7305  27.2625     27.9469     26.4222       27.4008
# 22     26.4305  25.6625     26.5469     25.5222       26.1008
# 23     22.7305  23.4625     23.8469     23.3222       23.5008
# 24     20.5305  20.0625     20.8469     20.5222       20.6008
# 25     22.1305  21.8625     22.8469     22.2222       22.4008
# 26     21.3305  22.1625     23.0469     22.2222       22.3008
# 27     23.2305  22.8625     23.9469     23.2222       23.4008
# 28     18.6305  19.9625     20.1469     19.9222       19.8008
# 29     27.7305  27.0625     28.0469     26.6222       27.5008
# 30     26.1305  25.7625     26.1469     24.9222       25.9008
# 31     20.9305  21.3625     22.4469     21.7222       21.7008
# 32     26.1305  25.9625     26.6469     25.6222       26.2008
# 33     20.1305  21.2625     21.6469     21.0222       21.1008
# 34     21.3305  22.3625     22.5469     22.3222       22.3008
# 35     23.5305  23.5625     24.5469     23.7222       24.0008
# 36     20.8305  20.7625     22.1469     21.3222       21.4008
# 37     23.5305  23.4625     24.4469     23.4222       23.8008
# 38     25.7305  25.3625     26.2469     25.0222       25.7008
# 39     26.3305  25.2625     26.7469     25.1222       26.0008
# 40     19.8305  20.5625     21.1469     20.6222       20.7008
# 41     23.0305  23.4625     24.3469     23.7222       23.8008
# 42     21.8305  21.1625     22.1469     21.6222       21.8008
# 43     21.8305  22.6625     23.1469     22.6222       22.7008
# 44     21.8305  21.8625     22.8469     22.3222       22.3008
# 45     25.6305  25.0625     26.4469     24.9222       25.6008
# 46     25.8305  25.2625     26.6469     25.2222       25.8008
# 47     23.2305  23.8625     24.1469     23.7222       23.9008
# 48     22.3305  21.3625     23.2469     22.2222       22.4008
# 49     22.0305  22.3625     22.6469     22.6222       22.5008
# 50     21.7305  21.7625     22.8469     22.3222       22.2008

# %% [markdown]
# ##### 14. Sort the dataframe by the values in a numeric column (e.g. observations descending by SAT participation rate)

# %%
both_sort = both.sort_values("SAT Participation Percent", ascending = False)
#Sorting the values in descending order by SAT Participation Rate

# %%
both_sort
#testing the output
# Out:
#                    State  SAT Participation Percent  SAT Reading and Writing  \
# 8   District of Columbia                        100                      482
# 22              Michigan                        100                      509
# 6            Connecticut                        100                      530
# 7               Delaware                        100                      503
# 29         New Hampshire                         96                      532
# 19                 Maine                         95                      513
# 12                 Idaho                         93                      513
# 9                Florida                         83                      520
# 21         Massachusetts                         76                      555
# 39          Rhode Island                         71                      539
# 30            New Jersey                         70                      530
# 20              Maryland                         69                      536
# 32              New York                         67                      528
# 46              Virginia                         65                      561
# 38          Pennsylvania                         65                      540
# 47            Washington                         64                      541
# 14               Indiana                         63                      542
# 43                 Texas                         62                      513
# 10               Georgia                         61                      535
# 45               Vermont                         60                      562
# 11                Hawaii                         55                      544
# 4             California                         53                      531
# 40        South Carolina                         50                      543
# 33        North Carolina                         49                      546
# 37                Oregon                         43                      560
# 1                 Alaska                         38                      547
# 2                Arizona                         30                      563
# 28                Nevada                         26                      563
# 48         West Virginia                         14                      558
# 35                  Ohio                         12                      578
# 5               Colorado                         11                      606
# 31            New Mexico                         11                      577
# 26               Montana                         10                      605
# 13              Illinois                          9                      559
# 36              Oklahoma                          7                      530
# 0                Alabama                          5                      593
# 42             Tennessee                          5                      623
# 17              Kentucky                          4                      631
# 16                Kansas                          4                      632
# 18             Louisiana                          4                      611
# 44                  Utah                          3                      624
# 49             Wisconsin                          3                      642
# 25              Missouri                          3                      640
# 41          South Dakota                          3                      612
# 27              Nebraska                          3                      629
# 23             Minnesota                          3                      644
# 3               Arkansas                          3                      614
# 50               Wyoming                          3                      626
# 34          North Dakota                          2                      635
# 24           Mississippi                          2                      634
# 15                  Iowa                          2                      641
#
#     SAT Math  SAT Total  ACT Participation Percent  ACT English  ACT Math  \
# 8        468        950                         32         24.4      23.5
# 22       495       1005                         29         24.1      23.7
# 6        512       1041                         31         25.5      24.6
# 7        492        996                         18         24.1      23.4
# 29       520       1052                         18         25.4      25.1
# 19       499       1012                          8         24.2      24.0
# 12       493       1005                         38         21.9      21.8
# 9        497       1017                         73         19.0      19.4
# 21       551       1107                         29         25.4      25.3
# 39       524       1062                         21         24.0      23.3
# 30       526       1056                         34         23.8      23.8
# 20       524       1060                         28         23.3      23.1
# 32       523       1052                         31         23.8      24.0
# 46       541       1102                         29         23.5      23.3
# 38       531       1071                         23         23.4      23.4
# 47       534       1075                         29         20.9      21.9
# 14       532       1074                         35         22.0      22.4
# 43       507       1020                         45         19.5      20.7
# 10       515       1050                         55         21.0      20.9
# 45       551       1114                         29         23.3      23.1
# 11       541       1085                         90         17.8      19.2
# 4        524       1055                         31         22.5      22.7
# 40       521       1064                        100         17.5      18.6
# 33       535       1081                        100         17.8      19.3
# 37       548       1108                         40         21.2      21.5
# 1        533       1080                         65         18.7      19.8
# 2        553       1116                         62         18.6      19.8
# 28       553       1116                        100         16.3      18.0
# 48       528       1086                         69         20.0      19.4
# 35       570       1149                         75         21.2      21.6
# 5        595       1201                        100         20.1      20.3
# 31       561       1138                         66         18.6      19.4
# 26       591       1196                        100         19.0      20.2
# 13       556       1115                         93         21.0      21.2
# 36       517       1047                        100         18.5      18.8
# 0        572       1165                        100         18.9      18.4
# 42       604       1228                        100         19.5      19.2
# 17       616       1247                        100         19.6      19.4
# 16       628       1260                         73         21.1      21.3
# 18       586       1198                        100         19.4      18.8
# 44       614       1238                        100         19.5      19.9
# 49       649       1291                        100         19.7      20.4
# 25       631       1271                        100         19.8      19.9
# 41       603       1216                         80         20.7      21.5
# 27       625       1253                         84         20.9      20.9
# 23       651       1295                        100         20.4      21.5
# 3        594       1208                        100         18.9      19.0
# 50       604       1230                        100         19.4      19.8
# 34       621       1256                         98         19.0      20.4
# 24       607       1242                        100         18.2      18.1
# 15       635       1275                         67         21.2      21.3
#
#     ACT Reading  ACT_Science  ACT Composite
# 8          24.9         23.5           24.2
# 22         24.5         23.8           24.1
# 6          25.6         24.6           25.2
# 7          24.8         23.6           24.1
# 29         26.0         24.9           25.5
# 19         24.8         23.7           24.3
# 12         23.0         22.1           22.3
# 9          21.0         19.4           19.8
# 21         25.9         24.7           25.4
# 39         24.7         23.4           24.0
# 30         24.1         23.2           23.9
# 20         24.2         23.2           23.6
# 32         24.6         23.9           24.2
# 46         24.6         23.5           23.8
# 38         24.2         23.3           23.7
# 47         22.1         22.0           21.9
# 14         23.2         22.3           22.6
# 43         21.1         20.9           20.7
# 10         22.0         21.3           21.4
# 45         24.4         23.2           23.6
# 11         19.2         19.3           19.0
# 4          23.1         22.2           22.8
# 40         19.1         18.9           18.7
# 33         19.6         19.3           19.1
# 37         22.4         21.7           21.8
# 1          20.4         19.9           19.8
# 2          20.1         19.8           19.7
# 28         18.1         18.2           17.8
# 48         21.2         20.5           20.4
# 35         22.5         22.0           22.0
# 5          21.2         20.9           20.8
# 31         20.4         20.0           19.7
# 26         21.0         20.5           20.3
# 13         21.6         21.3           21.4
# 36         20.1         19.6           19.4
# 0          19.7         19.4           19.2
# 42         20.1         19.9           19.8
# 17         20.5         20.1           20.0
# 16         22.3         21.7           21.7
# 18         19.8         19.6           19.5
# 44         20.8         20.6           20.3
# 49         20.6         20.9           20.5
# 25         20.8         20.5           20.4
# 41         22.3         22.0           21.8
# 27         21.9         21.5           21.4
# 23         21.8         21.6           21.5
# 3          19.7         19.5           19.4
# 50         20.8         20.6           20.2
# 34         20.5         20.6           20.3
# 24         18.8         18.8           18.6
# 15         22.6         22.1           21.9

# %% [markdown]
# ##### 15. Use a boolean filter to display only observations with a score above a certain threshold (e.g. only states with a participation rate above 50%)

# %%
both_50 = both_sort["SAT Participation Percent"] > 50

# %%
both_50
# Out:
# 8      True
# 22     True
# 6      True
# 7      True
# 29     True
# 19     True
# 12     True
# 9      True
# 21     True
# 39     True
# 30     True
# 20     True
# 32     True
# 46     True
# 38     True
# 47     True
# 14     True
# 43     True
# 10     True
# 45     True
# 11     True
# 4      True
# 40    False
# 33    False
# 37    False
# 1     False
# 2     False
# 28    False
# 48    False
# 35    False
# 5     False
# 31    False
# 26    False
# 13    False
# 36    False
# 0     False
# 42    False
# 17    False
# 16    False
# 18    False
# 44    False
# 49    False
# 25    False
# 41    False
# 27    False
# 23    False
# 3     False
# 50    False
# 34    False
# 24    False
# 15    False
# Name: SAT Participation Percent, dtype: bool

# %% [markdown]
# ## Step 3: Visualize the data

# %% [markdown]
# ##### 16. Using MatPlotLib and PyPlot, plot the distribution of the Rate columns for both SAT and ACT using histograms. (You should have two histograms. You might find [this link](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes) helpful in organizing one plot above the other.)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

both['SAT Participation Percent'].hist(bins=10);
plt.title('SAT Participation %')

# %%
# %matplotlib inline

both['ACT Participation Percent'].hist(bins=10);
plt.title('ACT Participation %')

# %% [markdown]
# ##### 17. Plot the Math(s) distributions from both data sets.

# %%
# %matplotlib inline

both['SAT Math'].hist(bins=10);
plt.title('SAT Math Score')

# %%
# %matplotlib inline

both['ACT Math'].hist(bins=10);
plt.title('ACT Math Score')

# %% [markdown]
# ##### 18. Plot the Verbal distributions from both data sets.

# %%
# %matplotlib inline

both['SAT Reading and Writing'].hist(bins=10);
plt.title('SAT Reading and Writing')

# %%
# %matplotlib inline

both['ACT English'].hist(bins=10);
plt.title('ACT English')

# %%
# %matplotlib inline

both['ACT Reading'].hist(bins=10);
plt.title('ACT Reading')

# %% [markdown]
# ##### 19. When we make assumptions about how data are distributed, what is the most common assumption?

# %%
"""We assume data follows a normal distribution"""

# %% [markdown]
# ##### 20. Does this assumption hold true for any of our columns? Which?

# %% [markdown]
# ##### 21. Plot some scatterplots examining relationships between all variables.

# %%
plt.scatter(both['SAT Participation Percent'], both['SAT Total'])
plt.title("SAT Total Score to Participation Percent")
plt.xlabel("SAT Participation Percent")
plt.ylabel("SAT Total")

# %%
plt.scatter(both['ACT Participation Percent'], both['ACT Composite'])
plt.title("ACT Composite Score to Participation Percent")
plt.xlabel("ACT Participation Percent")
plt.ylabel("ACT Composite")

# %% [markdown]
# ##### 22. Are there any interesting relationships to note?

# %%
#Both the totals for the ACT and SAT appear to be similar.

# %% [markdown]
# ##### 23. Create box plots for each variable.

# %%
sns.boxplot(data = sat, orient = "h")
#plotting the boxplot horizontally

# %%
sns.boxplot(data = act, orient = "h")
#plotting the boxplot horizontally

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.

# %% [markdown]
# ## Step 4: Descriptive and Inferential Statistics

# %% [markdown]
# ##### 24. Summarize each distribution. As data scientists, be sure to back up these summaries with statistics. (Hint: What are the three things we care about when describing distributions?)

# %%
#Based on the box graphs the results are close to each other.
#

# %%
#Center, Shape, and Spread

# %%
both.describe()
# Out:
#        SAT Participation Percent  SAT Reading and Writing    SAT Math  \
# count                  51.000000                51.000000   51.000000
# mean                   39.803922               569.117647  556.882353
# std                    35.276632                45.666901   47.121395
# min                     2.000000               482.000000  468.000000
# 25%                     4.000000               533.500000  523.500000
# 50%                    38.000000               559.000000  548.000000
# 75%                    66.000000               613.000000  599.000000
# max                   100.000000               644.000000  651.000000
#
#          SAT Total  ACT Participation Percent  ACT English   ACT Math  \
# count    51.000000                  51.000000    51.000000  51.000000
# mean   1126.098039                  65.254902    20.931373  21.182353
# std      92.494812                  32.140842     2.353677   1.981989
# min     950.000000                   8.000000    16.300000  18.000000
# 25%    1055.500000                  31.000000    19.000000  19.400000
# 50%    1107.000000                  69.000000    20.700000  20.900000
# 75%    1212.000000                 100.000000    23.300000  23.100000
# max    1295.000000                 100.000000    25.500000  25.300000
#
#        ACT Reading  ACT_Science  ACT Composite
# count    51.000000    51.000000      51.000000
# mean     22.013725    21.450980      21.519608
# std       2.067271     1.739353       2.020695
# min      18.100000    18.200000      17.800000
# 25%      20.450000    19.950000      19.800000
# 50%      21.800000    21.300000      21.400000
# 75%      24.150000    23.200000      23.600000
# max      26.000000    24.900000      25.500000

# %%
both.shape
# Out:
# (51, 11)

# %% [markdown]
# ##### 25. Summarize each relationship. Be sure to back up these summaries with statistics.

# %%
#Based on the scatterplots both graphs look similar in their layout of data

# %%
both.describe()
# Out:
#        SAT Participation Percent  SAT Reading and Writing    SAT Math  \
# count                  51.000000                51.000000   51.000000
# mean                   39.803922               569.117647  556.882353
# std                    35.276632                45.666901   47.121395
# min                     2.000000               482.000000  468.000000
# 25%                     4.000000               533.500000  523.500000
# 50%                    38.000000               559.000000  548.000000
# 75%                    66.000000               613.000000  599.000000
# max                   100.000000               644.000000  651.000000
#
#          SAT Total  ACT Participation Percent  ACT English   ACT Math  \
# count    51.000000                  51.000000    51.000000  51.000000
# mean   1126.098039                  65.254902    20.931373  21.182353
# std      92.494812                  32.140842     2.353677   1.981989
# min     950.000000                   8.000000    16.300000  18.000000
# 25%    1055.500000                  31.000000    19.000000  19.400000
# 50%    1107.000000                  69.000000    20.700000  20.900000
# 75%    1212.000000                 100.000000    23.300000  23.100000
# max    1295.000000                 100.000000    25.500000  25.300000
#
#        ACT Reading  ACT_Science  ACT Composite
# count    51.000000    51.000000      51.000000
# mean     22.013725    21.450980      21.519608
# std       2.067271     1.739353       2.020695
# min      18.100000    18.200000      17.800000
# 25%      20.450000    19.950000      19.800000
# 50%      21.800000    21.300000      21.400000
# 75%      24.150000    23.200000      23.600000
# max      26.000000    24.900000      25.500000

# %% [markdown]
# ##### 26. Execute a hypothesis test comparing the SAT and ACT participation rates. Use $\alpha = 0.05$. Be sure to interpret your results.

# %%
import scipy.stats as stats

# %%
mean_SAT_Part =  39.803922
sigma_SAT_Part = 35.276632

#SAT Participation Rates
stats.t.interval(alpha = 0.95, df = 50,loc = mean_SAT_Part,scale=sigma_SAT_Part) 

# I pulled the information from both.describe()
# Out:
# (-31.051278563670934, 110.65912256367093)

# %%
mean_ACT_Part =  65.254902
sigma_ACT_Part = 32.140842

#ACT Participation Rates
stats.t.interval(alpha = 0.95, df = 50,loc = mean_ACT_Part,scale=sigma_ACT_Part) 
# I pulled the information from both.describe()
# Out:
# (0.6981210069829018, 129.81168299301709)

# %% [markdown]
# ##### 27. Generate and interpret 95% confidence intervals for SAT and ACT participation rates.

# %%
#SAT Participation Rates
conf_level = .95
stats.norm.interval(conf_level, loc=mean_SAT_Part, scale=sigma_SAT_Part)
# I pulled the information from both.describe()
# Out:
# (-29.337006215873174, 108.94485021587317)

# %%
#ACT Participation Rates
conf_level = .95
stats.norm.interval(conf_level, loc=mean_ACT_Part, scale=sigma_ACT_Part)
# I pulled the information from both.describe()
# Out:
# (2.2600092472076838, 128.24979475279233)

# %% [markdown]
# ##### 28. Given your answer to 26, was your answer to 27 surprising? Why?

# %%
#I was expecting them to correlate more based on it being similar (Math Test).

# %% [markdown]
# ##### 29. Is it appropriate to generate correlation between SAT and ACT math scores? Why?

# %%
#No, because their doesn't appear to to be a relationship between the two
plt.scatter(both['ACT Math'], both['SAT Math'], color = ['blue',"red"])

# %% [markdown]
# ##### 30. Suppose we only seek to understand the relationship between SAT and ACT data in 2017. Does it make sense to conduct statistical inference given the data we have? Why?
